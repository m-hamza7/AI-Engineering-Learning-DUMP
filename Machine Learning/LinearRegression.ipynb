# %% [markdown]
# Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as mt
from sklearn.linear_model import LinearRegression as lr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split


df = pd.read_csv('StudentMarks.csv')
print(df)

X  = df[['HoursStudied']]
Y = df['Marks']

model = lr()

model.fit(X,Y)

print(model.predict([[6]]))

print("Coefficient:", model.coef_
      , "Intercept:", model.intercept_)
# Out:
#    Unnamed: 0    Name  HoursStudied  Marks
# 0           0     Ali             2     55
# 1           1    Sara             5     85
# 2           2   Ahmed             1     45
# 3           3   Usman             3     65
# 4           4  Ayesha             6     92
# 5           5   Bilal             2     58
# 6           6    Zara             4     75
# [93.32352941]
# Coefficient: [9.38235294] Intercept: 37.029411764705884
# c:\Users\muhmd\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)

print("Predictted values:", Y_pred)
print("Mean Absolute Error:", mean_absolute_error(Y_test, Y_pred))
print("Mean Squared Error:", mean_squared_error(Y_test, Y_pred))
print("R2 Score:", r2_score(Y_test, Y_pred))
# Out:
# Predictted values: [55.97297297 83.54054054]
# Mean Absolute Error: 1.216216216216214
# Mean Squared Error: 1.538349159970774
# R2 Score: 0.9931628926223521

# %%
results = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
print(results)
# Out:
#    Actual  Predicted
# 0      55  55.972973
# 1      85  83.540541

# %%
mt.scatter(X, Y, color='blue', label='Actual Data')
mt.plot(X, model.predict(X), color='red', label='Regression Line')
mt.xlabel('Hours Studied')
mt.ylabel('Marks')
mt.legend()
mt.show()

# %%
data = {
    "Hours": [1,2,3,4,5,6,7,8,5,7],
    "Attendance": [60,65,70,75,80,85,90,95,88,92],
    "Sleep": [5,6,6,7,7,8,8,8,7,8],
    "Marks": [45,50,58,63,70,75,85,92,78,88]
}

df2 = pd.DataFrame(data)
df2.to_csv('StudentData2.csv', index=False)


X2 = df2[["Hours","Attendance","Sleep"]]
Y2 = df2["Marks"]

print(X.shape)


X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.2, random_state=42,shuffle=True)
model = lr()
model.fit(X2_train, Y2_train)
# Out:
# (7, 1)
# LinearRegression()

# %%
#input_data = [[]]
#input_data  =input("Enter Hours, Attendance, Sleep (comma separated): ")
#input_data = list(map(float, input_data.split(',')))


prediction = model.predict(X2_test)
print("Predicted Marks:", prediction)


print("Coefficient:", model.coef_, "Intercept:", model.intercept_)  # Print the coefficients and intercept of the model.

mt.scatter(Y2_test, model.predict(X2_test), color='blue', label='Predicted vs Actual')

resultss = pd.DataFrame({'Actual': Y2_test, 'Predicted': model.predict(X2_test)})
print(resultss)
mt.xlabel('Actual Marks')
mt.ylabel('Predicted Marks')
mt.show()
# Out:
# Predicted Marks: [87.3 49.6]
# Coefficient: [-1.95  2.05 -3.6 ] Intercept: -58.14999999999995
#    Actual  Predicted
# 8      78       87.3
# 1      50       49.6

# %%
pred=model.predict(X2_test)

print("mean_absolute_error:", mean_absolute_error(Y2_test, pred))
print("mean_squared_error:", mean_squared_error(Y2_test, pred))
print("r2_score:", r2_score(Y2_test, pred))
# Out:
# mean_absolute_error: 4.849999999999994
# mean_squared_error: 43.325000000000095
# r2_score: 0.7789540816326526

# %%
from sklearn . preprocessing import PolynomialFeatures , StandardScaler
from sklearn . linear_model import LinearRegression
from sklearn . pipeline import Pipeline

pipe = Pipeline ([
('poly ', PolynomialFeatures ( degree =3, include_bias = True )),
('scaler ', StandardScaler ()),
('model ', LinearRegression ()),
])

pipe .fit( X2_train , Y2_train )
y_pred = pipe . predict ( X2_test )

print("Polynomial Regression - Mean Absolute Error:", mean_absolute_error(Y2_test, y_pred))
print("Polynomial Regression - Mean Squared Error:", mean_squared_error(Y2_test, y_pred))
print("Polynomial Regression - R2 Score:", r2_score(Y2_test, y_pred))
# Out:
# Polynomial Regression - Mean Absolute Error: 2.84595444946941
# Polynomial Regression - Mean Squared Error: 8.10141170452411
# Polynomial Regression - R2 Score: 0.9586662668136525
