# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as mt 

df = pd.read_csv('StudentData.csv')

print(df)
# Out:
#    Unnamed: 0  ID    Name  Math  Physics  English  Chemistry  Total  Average  \
# 0           0   0     Ali    78       85       70         88    321    80.25
# 1           1   1    Sara    92       89       95         90    366    91.50
# 2           2   2   Ahmed    65       70       60         72    267    66.75
# 3           3   3   Usman    88       76       84         80    328    82.00
# 4           4   4  Ayesha    95       98       92         94    379    94.75
# 5           5   5   Bilal    55       81       73         68    277    69.25
# 6           6   6    Zara    81       79       85         83    328    82.00
# 7           7   7  Hassan    73       68       75         70    286    71.50
# 8           8   8  Fatima    90       93       88         91    362    90.50
# 9           9   9    Omar    67       72       65         70    274    68.50
#
#   Grade  percentage
# 0     B       80.25
# 1     A       91.50
# 2     D       66.75
# 3     B       82.00
# ...

# %%
avg_total_marks = df['Total'].mean()
print("Average total marks of the class are:",avg_total_marks)
# Out:
# Average total marks of the class are: 318.8

# %%
median = df['Total'].median()
print("Median of total marks is:",median)
# Out:
# Median of total marks is: 324.5

# %%
mode = df['Total'].mode()
print("Mode of total marks is:",mode)
# Out:
# Mode of total marks is: 0    328
# Name: Total, dtype: int64

# %%
Range = df['Total'].max() - df['Total'].min()
print("Range of total marks is:",Range)
# Out:
# Range of total marks is: 112

# %%
Variance = df['Total'].var()
print("Variance of total marks is:",Variance)
# Out:
# Variance of total marks is: 1711.7333333333333

# %%
Standard_Deviation = df['Total'].std()
print("Standard Deviation of total marks is:",Standard_Deviation)
# Out:
# Standard Deviation of total marks is: 41.373099150696135

# %%
df2 = {  'Name': ['Ali', 'Sara', 'Ahmed', 'Usman', 'Ayesha', 'Bilal', 'Zara'],
        'HoursStudied': [2, 5, 1, 3, 6, 2, 4],
        'Marks': [55, 85, 45, 65, 92, 58, 75] }
print(df2)
df3 = pd.DataFrame(df2)
print(df3)
# Out:
# {'Name': ['Ali', 'Sara', 'Ahmed', 'Usman', 'Ayesha', 'Bilal', 'Zara'], 'HoursStudied': [2, 5, 1, 3, 6, 2, 4], 'Marks': [55, 85, 45, 65, 92, 58, 75]}
#      Name  HoursStudied  Marks
# 0     Ali             2     55
# 1    Sara             5     85
# 2   Ahmed             1     45
# 3   Usman             3     65
# 4  Ayesha             6     92
# 5   Bilal             2     58
# 6    Zara             4     75
